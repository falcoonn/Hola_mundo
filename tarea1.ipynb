# %% [markdown]
# <a href="https://colab.research.google.com/github/falcoonn/Hola_mundo/blob/main/tarea1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Convertir en dataframe
df= pd.read_csv("CountryTable.csv")
#df

# %%
#Imprimimos las primeras filas o registros del Dataframe
df.head(5)

# %%
#Filtro por objeto, se filtro la region del caribe
filtro1=df[df["region"] == "Caribbean"]
filtro1

# %%
#Convertir archivo filtrado a CSV
filtro1.to_csv("Entregable1.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable1.csv")

# %%
#Filtro por objeto, se filtro el nombre de francia
filtro1_2=df[df["name"] == "France"]
filtro1_2

# %%
#Convertir archivo filtrado a CSV
filtro1_2.to_csv("Entregable2.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable2.csv")

# %%
#Filtro por filas, se filtraron las filas 10, 20 y 30
#filtro2= df.iloc[300:302,: ]
filtro2=df.iloc[ [10, 20, 50] , : ]  #filas no consecutivas 
filtro2

# %%
#Convertir archivo filtrado a CSV
filtro2.to_csv("Entregable3.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable3.csv")

# %%
#Filtro por filas, se filtraron las filas 40, 60 y 80
#filtro2= df.iloc[300:302,: ]
filtro2_2=df.iloc[ [40, 60, 80] , : ]  #filas no consecutivas 
filtro2_2

# %%
#Convertir archivo filtrado a CSV
filtro2_2.to_csv("Entregable4.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable4.csv")

# %%
#Filtro por columnas, se filtraron las columnas de la 5 a la 9
filtro3=df.iloc[ : , 5:9]
#filtro3=df.iloc[ : , [1,4,6]]  #columnas no consecutivas 
filtro3

# %%
#Convertir archivo filtrado a CSV
filtro3.to_csv("Entregable5.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable5.csv")

# %%
#Filtro por columnas, se filtraron las columnas de la 3 a la 6
filtro3_2=df.iloc[ : , 3:6]
#filtro3=df.iloc[ : , [1,4,6]]  #columnas no consecutivas 
filtro3_2

# %%
#Convertir archivo filtrado a CSV
filtro3_2.to_csv("Entregable6.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable6.csv")

# %%
#Filtro de filas vs columnas 
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()
df = pd.read_csv(io.BytesIO(uploaded['CountryTable.csv']), index_col=2)

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas, se filtraron los contientes de africa y asia con su respectivo capital 
filtro4=df.loc[["Asia","Africa"], ["capital"]]
filtro4

# %%
#Convertir archivo filtrado a CSV
filtro4.to_csv("Entregable7.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable7.csv")

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas, se filtraron los contientes de europa y norte america con su respectivo capital 
filtro4_2=df.loc[["Europe","North America"], ["capital"]]
filtro4_2

# %%
#Convertir archivo filtrado a CSV
filtro4_2.to_csv("Entregable8.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable8.csv")

# %%
#Filtro por cabecera
filtro5=df.head()
filtro5

# %%
#Convertir archivo filtrado a CSV
filtro5.to_csv("Entregable9.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable9.csv")

# %%
#Filtro por cabecera
filtro5_2=df.head(4)
filtro5_2

# %%
#Convertir archivo filtrado a CSV
filtro5_2.to_csv("Entregable10.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable10.csv")

# %%
#Filtro por comparacion, se filtro el area de la superficie que fuera mayor a 1000
filtro6=df[df["surface_area"] > 1000]
filtro6

# %%
#Convertir archivo filtrado a CSV
filtro6.to_csv("Entregable11.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregabl11.csv")

# %%
#Filtro por comparacion, se filtro el gnp que fuera mayor a 500
filtro6_2=df[df["gnp"] > 500]
filtro6_2

# %%
#Convertir archivo filtrado a CSV
filtro6_2.to_csv("Entregable12.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable12.csv")

# %%
#Filtro Y, se filtro el area de la superficie mayor a 1000 y la region del caribe 
filtro7=df[(df["surface_area"] > 1000) & (df["region"] == "Caribean")]
filtro7

# %%
#Convertir archivo filtrado a CSV
filtro7.to_csv("Entregable13.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable13.csv")

# %%
#Filtro Y, se filtro el gnp mayor a 500 y la region de norte america 
filtro7_2=df[(df["gnp"] > 500) & (df["region"] == "North America")]
filtro7_2

# %%
#Convertir archivo filtrado a CSV
filtro7_2.to_csv("Entregable14.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable14.csv")

# %%
#Filtro o, se filtro el area de la superficie mayor a 1000 o la region del caribe
filtro8=df[(df["surface_area"] > 1000) | (df["region"] == "Caribean")]
filtro8

# %%
#Convertir archivo filtrado a CSV
filtro8.to_csv("Entregable15.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable15.csv")

# %%
#Filtro o, se filtro el gnp mayor a 500 o la region de norte america
filtro8_2=df[(df["gnp"] > 500) | (df["region"] == "North America")]
filtro8_2

# %%
#Convertir archivo filtrado a CSV
filtro8_2.to_csv("Entregable16.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable16.csv")

# %%
#Filtro not, se filtraron los datos del area de la superficie mayor 1000 y la region del caribe que no fueran mayor a 1000
filtro9=df[~(df["surface_area"] >= 1000) & ~(df["region"] == "Caribean")]
filtro9
# Out:
#               code                                  name  \
# continent
# North America  ABW                                 Aruba
# North America  AIA                              Anguilla
# Europe         AND                               Andorra
# North America  ANT                  Netherlands Antilles
# Oceania        ASM                        American Samoa
# North America  ATG                   Antigua and Barbuda
# Asia           BHR                               Bahrain
# North America  BMu                               Bermuda
# North America  BRB                              Barbados
# Antarctica     BVT                         Bouvet Island
# Oceania        CCK               Cocos (Keeling) Islands
# Oceania        COK                          Cook Islands
# Oceania        CXR                      Christmas Island
# North America  CYM                        Cayman Islands
# North America  DMA                              Dominica
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Entregable17.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable17.csv")

# %%
#Filtro not, se filtraron el gnp mayor igual a 500 y la region de norte america que no tuvieran el gnp mayor igual a 500
filtro9_2=df[~(df["gnp"] >= 500) & ~(df["region"] == "North America")]
filtro9_2

# %%
#Convertir archivo filtrado a CSV
filtro9_2.to_csv("Entregable18.csv")

# %%
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Entregable18.csv")
