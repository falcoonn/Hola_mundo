# %% [markdown]
# <a href="https://colab.research.google.com/github/falcoonn/Hola_mundo/blob/main/Extracci%C3%B3n_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerias requeridas
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
#Cargar archivos csv desde equipo
#from  google.colab import files
#files.upload()

# %%
#Cargar archivo csv desde seaborn
df=sns.load_dataset(name="titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Imprimimos las primeras filas o registros del Dataframe
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Filtro por objeto
filtro1=df[df["sex"]=="female"]
filtro1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Filtro por filas
#Filtro2=df.iloc[300:302,:]
filtro2=df.iloc[[886, 887, 888],:]#Filas no consecutivas
filtro2
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False

# %%
#Filtro por columnas y filas
#Filtro mix=df.iloc[[10,20,50] , 2:5]
filtro_mix=df.iloc[ : ,[1,3,8]] #Columnas no consecutivas
filtro_mix
# Out:
#      pclass   age   class
# 0         3  22.0   Third
# 1         1  38.0   First
# 2         3  26.0   Third
# 3         1  35.0   First
# 4         3  35.0   Third
# ..      ...   ...     ...
# 886       2  27.0  Second
# 887       1  19.0   First
# 888       3   NaN   Third
# 889       1  26.0   First
# 890       3  32.0   Third
#
# [891 rows x 3 columns]

# %%
#Convertir archivo filtrado a csv
df.to_csv("titanic")

# %%
#Descargar archivo filtrado en csv
from google.colab import files

files.download("titanic")

# %%
#Filtro de filas vs columnas
#Paso 1 : Leemos el contenido del archivo 
from google.colab import files
uploaded=files.upload()
df=pd.read_csv(io.BytesIO(uploaded["titanic"]), index_col=13)
df
# Out:
#      <input type="file" id="files-bdef5f1c-785f-4971-878f-84bc62658eff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdef5f1c-785f-4971-878f-84bc62658eff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Paso 2: Aplicamos filtro de filas vs columnas
filtro4 = df.loc[["Southampton","Cherbourg","Queenstown"],["class"]]
filtro4
# Out:
#              class
# embark_town
# Southampton  Third
# Southampton  Third
# Southampton  First
# Southampton  Third
# Southampton  First
# ...            ...
# Queenstown   Third
# Queenstown   Third
# Queenstown   Third
# Queenstown   Third
# Queenstown   Third
#
# [889 rows x 1 columns]

# %%
#Filtro por cabecera
filtro5=df.head()
filtro5
# Out:
#              Unnamed: 0  survived  pclass     sex   age  sibsp  parch  \
# embark_town
# Southampton           0         0       3    male  22.0      1      0
# Cherbourg             1         1       1  female  38.0      1      0
# Southampton           2         1       3  female  26.0      0      0
# Southampton           3         1       1  female  35.0      1      0
# Southampton           4         0       3    male  35.0      0      0
#
#                 fare embarked  class    who  adult_male deck alive  alone
# embark_town
# Southampton   7.2500        S  Third    man        True  NaN    no  False
# Cherbourg    71.2833        C  First  woman       False    C   yes  False
# Southampton   7.9250        S  Third  woman       False  NaN   yes   True
# Southampton  53.1000        S  First  woman       False    C   yes  False
# Southampton   8.0500        S  Third    man        True  NaN    no   True

# %%
#Filtro por comparación
filtro6=df[df["age"]>=20]
filtro6
# Out:
#              Unnamed: 0  survived  pclass     sex   age  sibsp  parch  \
# embark_town
# Southampton           0         0       3    male  22.0      1      0
# Cherbourg             1         1       1  female  38.0      1      0
# Southampton           2         1       3  female  26.0      0      0
# Southampton           3         1       1  female  35.0      1      0
# Southampton           4         0       3    male  35.0      0      0
# ...                 ...       ...     ...     ...   ...    ...    ...
# Southampton         884         0       3    male  25.0      0      0
# Queenstown          885         0       3  female  39.0      0      5
# Southampton         886         0       2    male  27.0      0      0
# Cherbourg           889         1       1    male  26.0      0      0
# Queenstown          890         0       3    male  32.0      0      0
#
#                 fare embarked   class    who  adult_male deck alive  alone
# embark_town
# ...

# %%
#Filtro y 
filtro7=df[(df["age"]== 25) & (df["sex"] == "male")]
filtro7
# Out:
#              Unnamed: 0  survived  pclass   sex   age  sibsp  parch     fare  \
# embark_town
# Southampton          75         0       3  male  25.0      0      0   7.6500
# Southampton         134         0       2  male  25.0      0      0  13.0000
# Southampton         267         1       3  male  25.0      1      0   7.7750
# Southampton         271         1       3  male  25.0      0      0   0.0000
# Southampton         343         0       2  male  25.0      0      0  13.0000
# Southampton         353         0       3  male  25.0      1      0  17.8000
# Cherbourg           370         1       1  male  25.0      1      0  55.4417
# Southampton         442         0       3  male  25.0      1      0   7.7750
# Cherbourg           484         1       1  male  25.0      1      0  91.0792
# Southampton         666         0       2  male  25.0      0      0  13.0000
# Cherbourg           685         0       2  male  25.0      1      2  41.5792
# ...

# %%
#Filtro creado por mi
filtro8=df[df["survived"]==1]
filtro8
# Out:
#              Unnamed: 0  survived  pclass     sex   age  sibsp  parch  \
# embark_town
# Cherbourg             1         1       1  female  38.0      1      0
# Southampton           2         1       3  female  26.0      0      0
# Southampton           3         1       1  female  35.0      1      0
# Southampton           8         1       3  female  27.0      0      2
# Cherbourg             9         1       2  female  14.0      1      0
# ...                 ...       ...     ...     ...   ...    ...    ...
# Cherbourg           875         1       3  female  15.0      0      0
# Cherbourg           879         1       1  female  56.0      0      1
# Southampton         880         1       2  female  25.0      0      1
# Southampton         887         1       1  female  19.0      0      0
# Cherbourg           889         1       1    male  26.0      0      0
#
#                 fare embarked   class    who  adult_male deck alive  alone
# embark_town
# ...

# %%
#Filtro o 
filtro9=df[(df["age"] >18) | (df["sex"]== "female") ]
filtro9
# Out:
#              Unnamed: 0  survived  pclass     sex   age  sibsp  parch  \
# embark_town
# Southampton           0         0       3    male  22.0      1      0
# Cherbourg             1         1       1  female  38.0      1      0
# Southampton           2         1       3  female  26.0      0      0
# Southampton           3         1       1  female  35.0      1      0
# Southampton           4         0       3    male  35.0      0      0
# ...                 ...       ...     ...     ...   ...    ...    ...
# Southampton         886         0       2    male  27.0      0      0
# Southampton         887         1       1  female  19.0      0      0
# Southampton         888         0       3  female   NaN      1      2
# Cherbourg           889         1       1    male  26.0      0      0
# Queenstown          890         0       3    male  32.0      0      0
#
#                 fare embarked   class    who  adult_male deck alive  alone
# embark_town
# ...

# %%
#Filtro not
filtro10=df[~(df["age"]>=18) & (df["sex"]=="female")]
filtro10
# Out:
#              Unnamed: 0  survived  pclass     sex   age  sibsp  parch  \
# embark_town
# Cherbourg             9         1       2  female  14.0      1      0
# Southampton          10         1       3  female   4.0      1      1
# Southampton          14         0       3  female  14.0      0      0
# Cherbourg            19         1       3  female   NaN      0      0
# Queenstown           22         1       3  female  15.0      0      0
# ...                 ...       ...     ...     ...   ...    ...    ...
# Cherbourg           852         0       3  female   9.0      1      1
# Southampton         853         1       1  female  16.0      0      1
# Southampton         863         0       3  female   NaN      8      2
# Cherbourg           875         1       3  female  15.0      0      0
# Southampton         888         0       3  female   NaN      1      2
#
#                 fare embarked   class    who  adult_male deck alive  alone
# embark_town
# ...

# %%
#Convertir archivo filtrado a csv 
filtro10.to_csv("entregable1.csv")

# %%
#Descargar archivo filtrado csv
from google.colab import files

files.download("entregable1.csv")
